# %% [markdown]
# ##### Import .env File

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)
assert(os.getenv("OPENAI_API_KEY")is not None)

# %% [markdown]
# ### Interfaces

# %% [markdown]
# #### LLM Interface

# %%
from langchain_openai.llms import OpenAI
model = OpenAI(model="babbage-002", temperature=0.1, max_tokens=3)
model.invoke("The sky is")
# Out:
# ' the limit for'

# %% [markdown]
# #### Chat Interface

# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
model = ChatOpenAI(model="gpt-3.5-turbo", temperature=0.1, max_tokens=3)
prompt = [HumanMessage("The sky is")]
model.invoke(prompt)
# Out:
# AIMessage(content=' blue and clear', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 3, 'prompt_tokens': 10, 'total_tokens': 13, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-BOQop0vIxwv1IxYzMTxcCWLEAGdk6', 'finish_reason': 'length', 'logprobs': None}, id='run-72778ebf-75cb-4b1e-94cf-f81d212bc89e-0', usage_metadata={'input_tokens': 10, 'output_tokens': 3, 'total_tokens': 13, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# Instead of single prompt string, chat models make use of different types of chat message interfaces associated with each role mentioned
# 1. Human Message
#     User
# 2. AI Message
#     AI
# 3. System Message
#     Instructions for AI to follow
# 4. Chat Message
#     A msg for allowing arbitary setting of role

# %% [markdown]
# ### Prompt Template Interface

# %%
from langchain_core.prompts import PromptTemplate
template = PromptTemplate.from_template("""
    Answer the following question with a single word.
    Context: {context}
    Question: {question}
    Answer:
    """)
prompt = template.invoke({
    "context": "Paris is the one of the cites of France, along with Lyon, Marseille, and Nice but others are not the capital.",
    "question": "What is the capital of France?"
})
model = ChatOpenAI(model="gpt-3.5-turbo", temperature=0.1, max_tokens=3)
response = model.invoke(prompt)
response
# Out:
# AIMessage(content='Paris', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2, 'prompt_tokens': 60, 'total_tokens': 62, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-BOQxTO1B5vcBBFiA3yj30NMYBw795', 'finish_reason': 'stop', 'logprobs': None}, id='run-adf2d36b-ec7b-4764-924a-fc0644ea749c-0', usage_metadata={'input_tokens': 60, 'output_tokens': 2, 'total_tokens': 62, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# Similarly Chat Prompt Template
from langchain_core.prompts import ChatPromptTemplate
template = ChatPromptTemplate.from_messages([
    ('system',"Answer the following question with a single word."),
    ('human',"Context: {context}"),
    ('human',"Question: {question}"),
    ('human',"Answer:")
])
prompt = template.invoke({
    "context": "Paris is the one of the cites of France, along with Lyon, Marseille, and Nice but others are not the capital.",
    "question": "What is the capital of France?"
})
model = ChatOpenAI(model="gpt-3.5-turbo", temperature=0.1, max_tokens=3)
response = model.invoke(prompt)
response
# Out:
# AIMessage(content='Paris', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2, 'prompt_tokens': 66, 'total_tokens': 68, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-BOSJKRPAGp5UnSl6iv4mN2BmGeHVk', 'finish_reason': 'stop', 'logprobs': None}, id='run-ebbabd1e-2dff-4ab0-a6be-447bdd5e603d-0', usage_metadata={'input_tokens': 66, 'output_tokens': 2, 'total_tokens': 68, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ### Structured Output

# %%
from langchain_openai import ChatOpenAI
from langchain_core.pydantic_v1 import BaseModel
class AnswerWithJustification(BaseModel):
    '''Answer to the user's question along with the justification''' #doc_string; access it like AnswerWithJustification.__doc__
    answer: str
    '''The answer to the user's question'''
    justification: str
    '''The justification for the answer'''

model = ChatOpenAI(model="gpt-4o-mini", temperature=0)
model_structured = model.with_structured_output(AnswerWithJustification)
model_structured.invoke("""What weights more, a pound of feathers or a pound of bricks?""")
#Output is a object of AnswerWithJustification with answer and justification attributes
# Out:
# d:\GitHub\GenAI\venv-genAI\Lib\site-packages\langchain_openai\chat_models\base.py:1660: UserWarning: Received a Pydantic BaseModel V1 schema. This is not supported by method="json_schema". Please use method="function_calling" or specify schema via JSON Schema or Pydantic V2 BaseModel. Overriding to method="function_calling".
#   warnings.warn(
# AnswerWithJustification(answer='A pound of feathers and a pound of bricks weigh the same: one pound.', justification='Weight is a measure of mass, and one pound is equal to one pound regardless of the material. Therefore, a pound of feathers weighs the same as a pound of bricks.')

# %% [markdown]
# Pydantic library is used for validating data against schemas
# Schema is sent to LLM in JSONSchema object and sent to LLM.
# Schema is also used to validate the output returned by LLM to see validity of output

# %% [markdown]
# #### Output Parsers

# %%
# 2 uses. Provide extra information to the model and get the answer in a structured format.
from langchain_core.output_parsers import CommaSeparatedListOutputParser
parser = CommaSeparatedListOutputParser()
items = parser.invoke("Red Car, Blue Car, Green Car")
items
# Out:
# ['Red Car', 'Blue Car', 'Green Car']

# %% [markdown]
# ### Assembling Many Pieces of an LLM Application

# %% [markdown]
# #### Runnable Interfaces

# %%
#1. Invoke 
#      single input to output
#2. Batch 
#      multiple inputs to multiple outputs
#3. Stream
#      output from single input as its produced (async)
from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-4o-mini", temperature=0)
completion = model.invoke('Hi There!')
print(completion)
completions = model.invoke(['Hi There!', 'Bye'])
print(completions)
for token in model.stream('Hi There!'):
    print(token)
# Out:
# content='Hello! How can I assist you today?' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 10, 'total_tokens': 20, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0392822090', 'id': 'chatcmpl-BORUT4MicydvfFadJp3yX8b7zSTuS', 'finish_reason': 'stop', 'logprobs': None} id='run-c6bc3cca-1a35-48aa-aec0-dbf376ce506e-0' usage_metadata={'input_tokens': 10, 'output_tokens': 10, 'total_tokens': 20, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# content="Hello! If you have any questions or need assistance, feel free to ask. If you're leaving, take care!" additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 15, 'total_tokens': 39, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_dbaca60df0', 'id': 'chatcmpl-BORUUiy06EzbvV44rImziwBifMYFQ', 'finish_reason': 'stop', 'logprobs': None} id='run-2380d220-949f-4117-937d-65fb99756bee-0' usage_metadata={'input_tokens': 15, 'output_tokens': 24, 'total_tokens': 39, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# content='' additional_kwargs={} response_metadata={} id='run-b8eb7c29-d747-4dea-9aca-fb5a94cb4f8f'
# content='Hello' additional_kwargs={} response_metadata={} id='run-b8eb7c29-d747-4dea-9aca-fb5a94cb4f8f'
# content='!' additional_kwargs={} response_metadata={} id='run-b8eb7c29-d747-4dea-9aca-fb5a94cb4f8f'
# content=' How' additional_kwargs={} response_metadata={} id='run-b8eb7c29-d747-4dea-9aca-fb5a94cb4f8f'
# content=' can' additional_kwargs={} response_metadata={} id='run-b8eb7c29-d747-4dea-9aca-fb5a94cb4f8f'
# content=' I' additional_kwargs={} response_metadata={} id='run-b8eb7c29-d747-4dea-9aca-fb5a94cb4f8f'
# content=' assist' additional_kwargs={} response_metadata={} id='run-b8eb7c29-d747-4dea-9aca-fb5a94cb4f8f'
# content=' you' additional_kwargs={} response_metadata={} id='run-b8eb7c29-d747-4dea-9aca-fb5a94cb4f8f'
# content=' today' additional_kwargs={} response_metadata={} id='run-b8eb7c29-d747-4dea-9aca-fb5a94cb4f8f'
# content='?' additional_kwargs={} response_metadata={} id='run-b8eb7c29-d747-4dea-9aca-fb5a94cb4f8f'
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_dbaca60df0'} id='run-b8eb7c29-d747-4dea-9aca-fb5a94cb4f8f'

# %% [markdown]
# #### Imperative Composition

# %% [markdown]
# ##### Basic

# %%
# fancy name for writing code in component-wise fashion
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import chain

template = ChatPromptTemplate.from_messages([
    ('system',"You are a helpful assistant."),
    ('human',"Question: {question}")
])

model = ChatOpenAI(model="gpt-4o-mini", temperature=0)

def chatbot(values):
    prompt = template.invoke(values)
    response = model.invoke(prompt)
    return response

print(chatbot({"question": "Best  GPT model for learning purposes?"}).content)
# Out:
# For learning purposes, the best GPT model to use often depends on your specific needs and goals. Here are a few options to consider:
#
# 1. **GPT-3.5**: This model is widely used and offers a good balance of performance and accessibility. It can handle a variety of tasks, including text generation, summarization, and question answering. It's a great choice for general learning and experimentation.
#
# 2. **GPT-4**: If you have access to GPT-4, it is more advanced than GPT-3.5 and can provide better responses, especially for complex queries. It is particularly useful for in-depth learning and understanding nuanced topics.
#
# 3. **OpenAI's Playground**: This is an interactive platform where you can experiment with different models, including GPT-3.5 and GPT-4. It allows you to test prompts and see how the models respond, which can be very educational.
#
# 4. **Fine-tuned Models**: Depending on your area of interest, you might find fine-tuned versions of GPT models that are specialized for certain tasks (like coding, medical information, etc.). These can be very useful for targeted learning.
#
# 5. **Open Source Alternatives**: If you're interested in the underlying technology and want to learn about model training and deployment, consider exploring open-source alternatives like GPT-Neo or GPT-J. These models can be run locally and modified for educational purposes.
#
# Ultimately, if you're looking for a model to learn from and experiment with, starting with GPT-3.5 or GPT-4 (if available) through OpenAI's API or Playground is a great choice.

# %% [markdown]
# ##### Streaming Imperative Composition

# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import chain

template = ChatPromptTemplate.from_messages([
    ('system',"You are a helpful assistant."),
    ('human',"Question: {question}")
])

@chain
def chatbot(values):
    prompt = template.invoke(values)
    for token in model.stream(prompt):
        yield token 

for part in chatbot.stream({"question": "Best  GPT model for learning purposes?"}):
    print(part)
# Out:
# content='' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='For' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' learning' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' purposes' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=',' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' the' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' best' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' GPT' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' model' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' to' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' use' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' often' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' depends' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' on' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' your' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' specific' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' needs' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' and' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' goals' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' Here' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' are' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' a' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' few' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' options' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' to' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' consider' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=':\n\n' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='1' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' **' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='GPT' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='-' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='3' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='5' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='**' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=':' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' This' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' model' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' is' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' widely' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' used' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' and' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' offers' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' a' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' good' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' balance' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' of' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' performance' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' and' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' accessibility' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' It' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' can' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' handle' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' a' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' variety' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' of' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' tasks' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=',' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' including' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' text' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' generation' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=',' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' summar' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='ization' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=',' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' and' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' question' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' answering' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=" It's" additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' a' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' great' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' choice' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' for' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' general' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' learning' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' and' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' experimentation' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='2' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' **' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='GPT' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='-' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='4' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='**' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=':' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' If' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' you' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' have' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' access' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' to' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' GPT' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='-' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='4' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=',' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' it' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' is' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' more' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' advanced' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' than' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' GPT' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='-' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='3' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='5' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' and' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' can' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' provide' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' better' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' performance' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' in' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' terms' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' of' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' understanding' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' context' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' and' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' generating' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' coherent' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' responses' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' It' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' is' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' particularly' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' useful' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' for' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' more' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' complex' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' tasks' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' and' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' nuanced' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' conversations' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='3' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' **' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='Open' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='AI' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content="'s" additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' Playground' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='**' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=':' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' This' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' is' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' an' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' interactive' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' platform' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' where' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' you' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' can' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' experiment' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' with' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' different' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' models' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=',' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' including' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' GPT' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='-' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='3' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='5' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' and' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' GPT' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='-' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='4' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' It' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' allows' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' you' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' to' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' test' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' prompts' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' and' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' see' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' how' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' the' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' models' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' respond' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=',' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' which' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' is' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' excellent' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' for' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' learning' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='4' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' **' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='Fine' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='-t' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='uned' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' Models' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='**' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=':' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' Depending' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' on' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' your' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' area' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' of' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' interest' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=',' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' you' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' might' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' find' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' fine' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='-t' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='uned' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' versions' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' of' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' GPT' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' models' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' that' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' are' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' specialized' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' for' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' certain' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' tasks' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' (' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='like' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' coding' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=',' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' medical' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' advice' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=',' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' etc' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.).' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' These' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' can' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' be' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' beneficial' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' if' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=" you're" additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' looking' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' to' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' learn' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' in' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' a' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' specific' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' domain' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='5' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' **' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='Open' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' Source' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' Alternatives' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='**' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=':' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' If' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=" you're" additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' interested' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' in' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' the' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' underlying' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' technology' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' and' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' want' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' to' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' learn' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' about' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' model' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' training' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' and' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' deployment' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=',' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' consider' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' exploring' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' open' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='-source' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' alternatives' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' like' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' GPT' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='-Ne' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='o' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' or' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' GPT' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='-J' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' These' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' models' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' can' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' be' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' run' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' locally' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' and' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' modified' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' for' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' educational' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' purposes' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='Ultimately' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=',' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' the' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' best' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' model' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' for' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' learning' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' will' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' depend' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' on' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' your' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' specific' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' objectives' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=',' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' whether' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=" you're" additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' looking' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' to' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' understand' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' the' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' technology' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=',' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' experiment' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' with' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' applications' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=',' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' or' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' learn' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' about' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' AI' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' in' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content=' general' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='.' additional_kwargs={} response_metadata={} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f7d56a8a2c'} id='run-7f1e1a8f-1d3f-4cf7-a1a1-c3b4feb30e11'

# %% [markdown]
# ##### Async Imperative Compostion

# %%
@chain 
async def chatbot(values):
    prompt = await template.ainvoke(values)
    return await model.ainvoke(prompt)

await chatbot.ainvoke({"question": "Best  GPT model for learning purposes?"})
# Out:
# AIMessage(content="For learning purposes, the best GPT model to use often depends on your specific needs and goals. Here are a few options to consider:\n\n1. **GPT-3.5**: This model is widely used and offers a good balance of performance and accessibility. It can handle a variety of tasks, including text generation, summarization, and question answering. It's a great choice for general learning and experimentation.\n\n2. **GPT-4**: If you have access to GPT-4, it is more advanced than GPT-3.5 and can provide better responses, especially for complex queries. It is particularly useful for in-depth learning and understanding nuanced topics.\n\n3. **OpenAI's Playground**: This is an interactive platform where you can experiment with different models, including GPT-3.5 and GPT-4. It allows you to test prompts and see how the models respond, which can be very educational.\n\n4. **Fine-tuned Models**: Depending on your area of interest, you might find fine-tuned versions of GPT models that are specialized for certain tasks (like coding, medical information, etc.). These can be very useful for targeted learning.\n\n5. **Open Source Alternatives**: If you're interested in the underlying technology and want to learn about model training and deployment, consider exploring open-source alternatives like GPT-Neo or GPT-J. These models can be run locally and modified for educational purposes.\n\nUltimately, if you're just starting out, GPT-3.5 or GPT-4 via OpenAI's API or Playground would be the most user-friendly and effective for learning.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 320, 'prompt_tokens': 27, 'total_tokens': 347, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f7d56a8a2c', 'id': 'chatcmpl-BORzth5tT97nRZCOLqEKR1COsh8Ns', 'finish_reason': 'stop', 'logprobs': None}, id='run-6bdaa51d-0a23-4a95-ba70-9a115c024dbc-0', usage_metadata={'input_tokens': 27, 'output_tokens': 320, 'total_tokens': 347, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# #### Declarative Composition

# %%
#LCEL: Declarative language for composing Langchain components
#Optimised for Parallel execution, Streaming, tracing, and async support

from langchain_openai.chat_models import ChatOpenAI 
from langchain_core.prompts import ChatPromptTemplate

template = ChatPromptTemplate.from_messages([
    ('system',"You are a helpful assistant."),
    ('human',"Question: {question}")
])

model = ChatOpenAI(model="gpt-4o-mini", temperature=0)
chatbot = template | model
chatbot.invoke({"question": "Best  GPT model for learning purposes?"})
# Out:
# AIMessage(content="For learning purposes, the best GPT model to use often depends on your specific needs and goals. Here are a few options to consider:\n\n1. **GPT-3.5**: This model is widely used and offers a good balance of performance and accessibility. It can handle a variety of tasks, including text generation, summarization, and question answering. It's a great choice for general learning and experimentation.\n\n2. **GPT-4**: If you have access to GPT-4, it is more advanced than GPT-3.5 and can provide better performance in terms of understanding context, generating coherent text, and handling complex queries. It’s ideal for more in-depth learning and applications that require higher accuracy.\n\n3. **OpenAI's Playground**: This is a user-friendly interface that allows you to experiment with different models, including GPT-3.5 and GPT-4. It’s a great way to learn how to interact with the models and understand their capabilities.\n\n4. **Fine-tuned Models**: Depending on your area of interest, you might find fine-tuned versions of GPT models that are specialized for certain tasks (like coding, medical advice, etc.). These can be beneficial if you want to learn about a specific domain.\n\n5. **Open Source Alternatives**: If you are interested in the underlying technology and want to learn about model training and deployment, consider exploring open-source alternatives like GPT-Neo or GPT-J. These models can be run locally and modified for educational purposes.\n\nUltimately, if you're just starting, GPT-3.5 or the OpenAI Playground is a great place to begin. If you have more advanced needs or access, GPT-4 would be the best choice for learning about the latest capabilities in AI language models.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 355, 'prompt_tokens': 27, 'total_tokens': 382, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f7d56a8a2c', 'id': 'chatcmpl-BOS0R5H1uFEvKNqoL3SvBgDZoypz3', 'finish_reason': 'stop', 'logprobs': None}, id='run-996d5928-ae66-4299-b011-488e8814b877-0', usage_metadata={'input_tokens': 27, 'output_tokens': 355, 'total_tokens': 382, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
#also either use following
await chatbot.ainvoke({"question": "Best  GPT model for learning purposes?"})
# Out:
# AIMessage(content="For learning purposes, the best GPT model to use often depends on your specific needs and goals. Here are a few options to consider:\n\n1. **GPT-3.5**: This model is widely used and offers a good balance of performance and accessibility. It can handle a variety of tasks, including text generation, summarization, and question answering. It's a great choice for general learning and experimentation.\n\n2. **GPT-4**: If you have access to GPT-4, it is more advanced than GPT-3.5 and can provide better responses, especially for complex queries. It is particularly useful for in-depth learning and understanding nuanced topics.\n\n3. **OpenAI's Playground**: This is an interactive platform where you can experiment with different models, including GPT-3.5 and GPT-4. It allows you to test prompts and see how the models respond, which can be very educational.\n\n4. **Fine-tuned Models**: Depending on your area of interest, you might find fine-tuned versions of GPT models that are specialized for certain tasks (like coding, medical information, etc.). These can be very useful for targeted learning.\n\n5. **Open Source Alternatives**: If you're interested in the underlying technology and want to learn about model training and deployment, consider exploring open-source alternatives like GPT-Neo or GPT-J. These models can be run locally and modified for educational purposes.\n\nUltimately, the best model for you will depend on what you want to learn and how you plan to use the model. If you're just starting, GPT-3.5 or the OpenAI Playground is a great place to begin.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 331, 'prompt_tokens': 27, 'total_tokens': 358, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f7d56a8a2c', 'id': 'chatcmpl-BOS9OmfrgeUloM40UN18ShTQniz9D', 'finish_reason': 'stop', 'logprobs': None}, id='run-2420c40c-8614-4cf0-813d-d8b15037bbc6-0', usage_metadata={'input_tokens': 27, 'output_tokens': 331, 'total_tokens': 358, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
for part in chatbot.stream({"question": "Best  GPT model for learning purposes?"}):
    print(part)
# Out:
# content='' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='For' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' learning' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' purposes' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=',' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' the' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' best' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' GPT' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' model' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' to' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' use' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' often' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' depends' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' on' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' your' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' specific' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' needs' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' and' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' goals' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' Here' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' are' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' a' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' few' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' options' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' to' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' consider' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=':\n\n' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='1' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' **' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='GPT' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='-' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='3' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='5' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='**' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=':' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' This' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' model' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' is' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' widely' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' used' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' and' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' offers' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' a' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' good' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' balance' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' of' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' performance' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' and' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' accessibility' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' It' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' can' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' handle' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' a' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' variety' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' of' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' tasks' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=',' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' including' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' text' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' generation' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=',' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' summar' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='ization' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=',' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' and' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' question' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' answering' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=" It's" additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' a' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' great' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' choice' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' for' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' general' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' learning' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' and' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' experimentation' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='2' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' **' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='GPT' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='-' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='4' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='**' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=':' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' If' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' you' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' have' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' access' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' to' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' GPT' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='-' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='4' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=',' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' it' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' is' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' more' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' advanced' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' than' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' GPT' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='-' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='3' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='5' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' and' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' can' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' provide' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' better' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' responses' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=',' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' especially' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' for' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' complex' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' queries' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' It' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' is' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' particularly' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' useful' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' for' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' in' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='-depth' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' learning' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' and' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' understanding' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' nuanced' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' topics' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='3' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' **' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='Open' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='AI' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content="'s" additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' Playground' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='**' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=':' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' This' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' is' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' an' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' interactive' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' platform' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' where' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' you' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' can' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' experiment' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' with' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' different' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' models' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=',' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' including' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' GPT' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='-' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='3' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='5' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' and' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' GPT' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='-' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='4' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' It' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' allows' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' you' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' to' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' test' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' prompts' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' and' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' see' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' how' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' the' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' models' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' respond' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=',' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' which' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' can' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' be' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' very' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' educational' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='4' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' **' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='Fine' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='-t' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='uned' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' Models' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='**' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=':' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' Depending' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' on' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' your' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' area' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' of' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' interest' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=',' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' you' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' might' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' find' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' fine' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='-t' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='uned' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' versions' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' of' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' GPT' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' models' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' that' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' are' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' specialized' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' for' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' certain' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' tasks' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' (' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='like' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' coding' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=',' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' medical' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' information' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=',' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' etc' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.).' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' These' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' can' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' be' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' very' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' useful' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' for' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' targeted' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' learning' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='5' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' **' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='Open' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' Source' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' Alternatives' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='**' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=':' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' If' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=" you're" additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' interested' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' in' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' the' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' underlying' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' technology' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' and' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' want' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' to' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' learn' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' about' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' model' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' training' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' and' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' deployment' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=',' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' consider' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' exploring' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' open' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='-source' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' alternatives' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' like' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' GPT' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='-Ne' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='o' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' or' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' GPT' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='-J' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' These' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' models' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' can' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' be' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' run' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' locally' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' and' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' modified' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' for' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' educational' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' purposes' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='Ultimately' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=',' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' the' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' best' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' model' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' for' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' you' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' will' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' depend' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' on' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' what' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' you' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' want' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' to' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' learn' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' and' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' how' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' you' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' plan' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' to' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' use' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' the' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' model' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' If' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=" you're" additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' just' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' starting' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=',' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' GPT' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='-' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='3' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='5' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' or' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' the' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' Open' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='AI' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' Playground' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' is' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' a' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' great' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' place' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' to' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content=' begin' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='.' additional_kwargs={} response_metadata={} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_f7d56a8a2c'} id='run-19e12f96-9a56-47b0-b029-8caf0c7e5d74'
